# %%
# import data

import pandas as pd

filename = 'data/mmm_data.csv'
try:
    df = pd.read_csv(filename)
except FileNotFoundError:
    print(f'Could not locate data file with filename {filename}. Check file path')
print(f'The shape of the dataset is: {df.shape}')
display(df.head())
# Out:
# The shape of the dataset is: (6240, 17)
#     geo        time  Channel0_impression  Channel1_impression  \
# 0  Geo0  2021-01-25               280668                    0
# 1  Geo0  2021-02-01               366206               182108
# 2  Geo0  2021-02-08               197565               230170
# 3  Geo0  2021-02-15               140990                66643
# 4  Geo0  2021-02-22               399116               164991
#
#    Channel2_impression  Channel3_impression  competitor_sales_control  \
# 0                    0               470611                 -1.338765
# 1                19825               527702                  0.893645
# 2                    0               393618                 -0.284549
# 3                    0               326034                 -1.034740
# 4                    0               381982                 -0.319276
#
#    sentiment_score_control  Channel0_spend  Channel1_spend  Channel2_spend  \
# ...
